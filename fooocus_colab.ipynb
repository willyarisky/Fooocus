# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/willyarisky/Fooocus.git
# %cd /content/Fooocus
# !pip install uv
# !uv pip install numpy==1.26.4 cupy-cuda12x
# !python entry_with_update.py --share --always-high-vram
